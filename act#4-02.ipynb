# %%
import numpy as np
import matplotlib.pyplot as plt
import control as ctrl

# %%
# Define transfer function
num = [1]
den = [1, 2, 1]

# %%
system = ctrl.TransferFunction(num, den)

# %%
# Get poles and zeros 
poles = ctrl.poles(system)
zeros = ctrl.zeros(system)

# %%
print("Transfer Function:")
print(system)
# Out:
# Transfer Function:
# <TransferFunction>: sys[0]
# Inputs (1): ['u[0]']
# Outputs (1): ['y[0]']
#
#         1
#   -------------
#   s^2 + 2 s + 1

# %%
print("\nPoles:", poles)
print("Zeros:", zeros)
# Out:
# Poles: [-1.+0.j -1.+0.j]
# Zeros: []

# %%
# Plot pole-zero map
plt.figure()
ctrl.pzmap(system, grid=True)
plt.title("Pole-Zero Map")
plt.show()
